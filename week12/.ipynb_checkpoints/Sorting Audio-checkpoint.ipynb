# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display
import IPython.display

# %%
# Load audio
filename='kingsLoop.wav'
y, sr = librosa.load(filename)

n_fft=2048
hop_length=512
win_length=512

# Let's make and display a mel-scaled power (energy-squared) spectrogram
s = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=128)

# Convert to log scale (dB). We'll use the peak power (max) as reference.
log_S = librosa.power_to_db(S, ref=np.max)

# Harmonic-percussive source separation
y_harmonic, y_percussive = librosa.effects.hpss(y)

# We'll use a CQT-based chromagram here.  An STFT-based implementation also exists in chroma_cqt()
# We'll use the harmonic component to avoid pollution from transients
C = librosa.feature.chroma_cqt(y=y_harmonic, sr=sr, hop_length=hop_length)

# %%
plt.figure
librosa.display.specshow(C, sr=sr, y_axis='chroma', vmin=0.0, vmax=1.0, x_axis='time')

# %%
Cmean=C.mean(axis=0)
idx=Cmean.argsort()

# %%
plt.figure
librosa.display.specshow(C[:,idx], sr=sr, y_axis='chroma', vmin=0.0, vmax=1.0, x_axis='time')

# %%
plt.figure
librosa.display.specshow(S, sr=sr, y_axis='chroma', vmin=0.0, vmax=1.0, x_axis='time')

# %%
plt.figure
librosa.display.specshow(S[:,idx], sr=sr, y_axis='chroma', vmin=0.0, vmax=1.0, x_axis='time')

# %%
# run inverse fourier transform on sorted spectrogram
newSig=librosa.core.istft(S[:,idx])
newSig=newSig*.1

# %%
IPython.display.Audio(data=newSig, rate=5444)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
idxRev=np.flip(idx,axis=0)
newSig=librosa.core.istft(S[:,idxRev])
newSig=newSig*.1
IPython.display.Audio(data=newSig, rate=5444)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure
plt.plot(y)

# %%
librosa.output.write_wav('test.wav', newSig, 2712, norm=False)

# %%
newSig.shape
# Out:
# (18207,)

# %%
# Out:
# (148043,)

# %%
# Out:
# 2711.8090689867136

# %%
hop_length
# Out:
# 512.0
