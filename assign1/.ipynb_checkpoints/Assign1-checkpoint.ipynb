# %% [markdown]
# Assignment 1 Answers

# %%
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt

# %% [markdown]
# Load R1

# %%
r1 = 'r1.wav'
r1sig , r1sr = librosa.load(r1,mono=True,sr=None)
r1time=np.arange(0,r1sig.shape[0])/r1sr

# %% [markdown]
# Plot time-domain representation of R1

# %%
plt.plot(r1time,r1sig)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('R1 Waveform')
# Out:
# Text(0.5,1,'R1 Waveform')

# %% [markdown]
# Plot time-domain representation of R1 zoomed in to 15–25 seconds, -0.5–0.5 amplitude

# %%
plt.plot(r1time,r1sig)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('R1 Waveform')
plt.xlim(15,25)
plt.ylim(-.5,.5)
# Out:
# (-0.5, 0.5)

# %% [markdown]
# Plot linear spectrogram of R1

# %%
r1spec = librosa.amplitude_to_db(np.abs(librosa.stft(r1sig)), ref=np.max)

# %%
librosa.display.specshow(r1spec, y_axis='linear')
plt.colorbar(format='%+2.0f dB')
plt.title('R1 Linear-frequency power spectrogram')
# Out:
# Text(0.5,1,'R1 Linear-frequency power spectrogram')

# %% [markdown]
# Log spectrogram of R1

# %%
librosa.display.specshow(r1spec, y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('R1 Log-frequency power spectrogram')
# Out:
# Text(0.5,1,'R1 Log-frequency power spectrogram')

# %% [markdown]
# Load R2

# %%
r2 = 'r2.wav'
r2sig , r2sr = librosa.load(r2,mono=True,sr=None)
r2time=np.arange(0,r2sig.shape[0])/r2sr

# %% [markdown]
# Plot time-domain representation of R2

# %%
plt.plot(r1time,r1sig)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('R2 Waveform')
# Out:
# Text(0.5,1,'R2 Waveform')

# %% [markdown]
# Plot time-domain representation of R2 zoomed in to 0–10 seconds, -0.8–0.8 amplitude

# %%
plt.plot(r1time,r1sig)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('R2 Waveform')
plt.xlim(0,10)
plt.ylim(-.8,.8)
# Out:
# (-0.8, 0.8)

# %% [markdown]
# Linear Spectrogram of R2

# %%
r2spec = librosa.amplitude_to_db(np.abs(librosa.stft(r2sig)), ref=np.max)

# %%
librosa.display.specshow(r2spec, y_axis='linear')
plt.colorbar(format='%+2.0f dB')
plt.title('R2 Linear-frequency power spectrogram')
# Out:
# Text(0.5,1,'R2 Linear-frequency power spectrogram')

# %%
librosa.display.specshow(r2spec, y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('R2 Log-frequency power spectrogram')
# Out:
# Text(0.5,1,'R2 Log-frequency power spectrogram')
